# %%
##importing libraries
import pandas as pd

# %%
##bring the data in
df = pd.read_csv("data/raw-data.csv")
df
# Out:
#           Prop ID AMPSDistrict  Inspection ID  Season  Round  \
# 0            X028           04         135710  Summer      3
# 1        M010-241           13         135716  Summer      4
# 2         Q104-02           01         135720  Summer      4
# 3            X196           12         135735  Summer      4
# 4       B073-ZN05           19         135743  Summer      4
# ...           ...          ...            ...     ...    ...
# 134714  X092-ZN03           13         111707    Fall      2
# 134715  B082-ZN01           10         111708    Fall      2
# 134716  B073-ZN17           19         111710    Fall      2
# 134717  B073-ZN10           19         111711    Fall      2
# 134718  R065-ZN02           02         111712    Fall      2
#
#                           Date BeginInspection EndInspection  Inspection Year  \
# 0       07/15/2020 12:00:00 AM        03:00 PM      03:50 PM             2020
# ...

# %%
##what do we have?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134719 entries, 0 to 134718
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Prop ID               134719 non-null  object
#  1   AMPSDistrict          134250 non-null  object
#  2   Inspection ID         134719 non-null  int64
#  3   Season                134719 non-null  object
#  4   Round                 134719 non-null  int64
#  5   Date                  134719 non-null  object
#  6   BeginInspection       134683 non-null  object
#  7   EndInspection         134702 non-null  object
#  8   Inspection Year       134719 non-null  int64
#  9   inspector             134719 non-null  int64
#  10  inspector2            2576 non-null    float64
#  11  Overall Condition     134719 non-null  object
#  12  Cleanliness           134719 non-null  object
#  13  Safety Condition      891 non-null     object
# ...

# %%
##df.query isnt working outirght, now i am going to rename the column before trying again
df.rename(columns = {'Inspection Year':'inspection_year'}, inplace = True)
df
# Out:
#           Prop ID AMPSDistrict  Inspection ID  Season  Round  \
# 0            X028           04         135710  Summer      3
# 1        M010-241           13         135716  Summer      4
# 2         Q104-02           01         135720  Summer      4
# 3            X196           12         135735  Summer      4
# 4       B073-ZN05           19         135743  Summer      4
# ...           ...          ...            ...     ...    ...
# 134714  X092-ZN03           13         111707    Fall      2
# 134715  B082-ZN01           10         111708    Fall      2
# 134716  B073-ZN17           19         111710    Fall      2
# 134717  B073-ZN10           19         111711    Fall      2
# 134718  R065-ZN02           02         111712    Fall      2
#
#                           Date BeginInspection EndInspection  inspection_year  \
# 0       07/15/2020 12:00:00 AM        03:00 PM      03:50 PM             2020
# ...

# %%
##let's only pull the year 2023
df_23 = df.query("`inspection_year` == 2023")
df_23
# Out:
#           Prop ID AMPSDistrict  Inspection ID Season  Round  \
# 265          RZ75           02         179672   Fall      2
# 266     R065-ZN09           02         179673   Fall      2
# 267     B065-ZN10           13         179674   Fall      2
# 268     X002-ZN06           14         179676   Fall      2
# 269     X003-ZN01           11         179679   Fall      2
# ...           ...          ...            ...    ...    ...
# 134648    X348-01           04         179813   Fall      3
# 134649       B292           02         179818   Fall      3
# 134650       R078           01         179827   Fall      3
# 134651       M223           09         179833   Fall      3
# 134652      RZ157           02         179837   Fall      3
#
#                           Date BeginInspection EndInspection  inspection_year  \
# 265     09/22/2023 12:00:00 AM        08:58 AM      09:08 AM             2023
# 266     09/22/2023 12:00:00 AM        09:13 AM      09:55 AM             2023
# ...
